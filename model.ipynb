# %% [markdown]
# # Importing Model and Saving locally

# %%
from transformers import pipeline

comment_emo = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-emotion") 

result = comment_emo("i love eating cheeseburgers")
print(result)
# Out:
# ...
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# [{'label': 'optimism', 'score': 0.9571099281311035}]
